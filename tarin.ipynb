# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense , Dropout
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
sz = 128
# Step 1 - Building the CNN

# Initializing the CNN
classifier = Sequential()

# First convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), input_shape=(sz, sz, 1), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
# Second convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))



# Flattening the layers
classifier.add(Flatten())

# Adding a fully connected layer
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=96, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dense(units=27, activation='softmax')) # softmax for more than 2

# Compiling the CNN
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # categorical_crossentropy for more than 2


# Step 2 - Preparing the train/test data and training the model
classifier.summary()
# Code copied from - https://keras.io/preprocessing/image/
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('data2/train',
                                                 target_size=(sz, sz),
                                                 batch_size=10,
                                                 color_mode='grayscale',
                                                 class_mode='categorical')

test_set = test_datagen.flow_from_directory('data2/test',
                                            target_size=(sz , sz),
                                            batch_size=10,
                                            color_mode='grayscale',
                                            class_mode='categorical') 
classifier.fit(
        training_set,
        steps_per_epoch=1284, # No of images in training set
        batch_size=10,
        epochs=10,
        validation_data=test_set,
        #validation_steps=4268 No of images in test set
        validation_steps=426)

# Saving the model
model_json = classifier.to_json()
with open("model-bw.json", "w") as json_file:
    json_file.write(model_json)
print('Model Saved')
classifier.save_weights('model-bw.h5')
print('Weights saved')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               3686528
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 96)                12384
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                6208
# _________________________________________________________________
# dense_19 (Dense)             (None, 27)                1755
# =================================================================
# Total params: 3,716,443
# Trainable params: 3,716,443
# Non-trainable params: 0
# _________________________________________________________________
# Found 12845 images belonging to 27 classes.
# Found 4268 images belonging to 27 classes.
# Epoch 1/10
# 1284/1284 [==============================] - 151s 117ms/step - loss: 2.8145 - accuracy: 0.1685 - val_loss: 0.2862 - val_accuracy: 0.9322
# Epoch 2/10
# 1284/1284 [==============================] - 156s 121ms/step - loss: 0.6771 - accuracy: 0.7728 - val_loss: 0.0660 - val_accuracy: 0.9824
# Epoch 3/10
# 1284/1284 [==============================] - 189s 148ms/step - loss: 0.4069 - accuracy: 0.8664 - val_loss: 0.0398 - val_accuracy: 0.9901
# Epoch 4/10
# 1284/1284 [==============================] - 203s 158ms/step - loss: 0.3163 - accuracy: 0.8983 - val_loss: 0.0146 - val_accuracy: 0.9958
# Epoch 5/10
# 1284/1284 [==============================] - 199s 155ms/step - loss: 0.2519 - accuracy: 0.9230 - val_loss: 0.0092 - val_accuracy: 0.9986
# Epoch 6/10
# 1284/1284 [==============================] - 214s 167ms/step - loss: 0.1998 - accuracy: 0.9358 - val_loss: 0.0132 - val_accuracy: 0.9967
# Epoch 7/10
# 1284/1284 [==============================] - 189s 147ms/step - loss: 0.1920 - accuracy: 0.9407 - val_loss: 0.0076 - val_accuracy: 0.9977
# Epoch 8/10
# 1284/1284 [==============================] - 168s 131ms/step - loss: 0.1553 - accuracy: 0.9502 - val_loss: 0.0104 - val_accuracy: 0.9960
# Epoch 9/10
# 1284/1284 [==============================] - 168s 131ms/step - loss: 0.1506 - accuracy: 0.9512 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 10/10
# 1284/1284 [==============================] - 170s 133ms/step - loss: 0.1385 - accuracy: 0.9553 - val_loss: 0.0046 - val_accuracy: 0.9991
# Model Saved
# Weights saved
